# %%
import pandas as pd

# %%
df = pd.read_json("fashion_products_dataset.json")

# %%
df
# Out:
#       actual_price average_rating brand                  category  \
# 0            2,999            3.9  York  Clothing and Accessories
# 1            1,499            3.9  York  Clothing and Accessories
# 2            2,999            3.9  York  Clothing and Accessories
# 3            2,999            3.9  York  Clothing and Accessories
# 4            2,999            3.9  York  Clothing and Accessories
# ...            ...            ...   ...                       ...
# 29995        2,299                  Oka  Clothing and Accessories
# 29996          799            3.8   Oka  Clothing and Accessories
# 29997        4,999                  Oka  Clothing and Accessories
# 29998        3,125            3.8   Oka  Clothing and Accessories
# 29999        3,125                  Oka  Clothing and Accessories
#
#                crawled_at                                        description  \
# 0     2021-02-10 20:11:51  Yorker trackpants made from 100% rich combed c...
# ...

# %%
df.head()
# Out:
#                                     _id actual_price average_rating brand  \
# 0  fa8e22d6-c0b6-5229-bb9e-ad52eda39a0a        2,999            3.9  York
# 1  893e6980-f2a0-531f-b056-34dd63fe912c        1,499            3.9  York
# 2  eb4c8eab-8206-59d0-bcd1-a724d96bf74f        2,999            3.9  York
# 3  3f3f97bb-5faf-57df-a9ff-1af24e2b1045        2,999            3.9  York
# 4  750caa3d-6264-53ca-8ce1-94118a1d8951        2,999            3.9  York
#
#                    category          crawled_at  \
# 0  Clothing and Accessories 2021-02-10 20:11:51
# 1  Clothing and Accessories 2021-02-10 20:11:52
# 2  Clothing and Accessories 2021-02-10 20:11:52
# 3  Clothing and Accessories 2021-02-10 20:11:53
# 4  Clothing and Accessories 2021-02-10 20:11:53
#
#                                          description discount  \
# 0  Yorker trackpants made from 100% rich combed c...  69% off
# 1  Yorker trackpants made from 100% rich combed c...  66% off
# ...

# %%
df.drop(columns='_id',inplace=True)

# %%
df
# Out:
#       actual_price average_rating brand                  category  \
# 0            2,999            3.9  York  Clothing and Accessories
# 1            1,499            3.9  York  Clothing and Accessories
# 2            2,999            3.9  York  Clothing and Accessories
# 3            2,999            3.9  York  Clothing and Accessories
# 4            2,999            3.9  York  Clothing and Accessories
# ...            ...            ...   ...                       ...
# 29995        2,299                  Oka  Clothing and Accessories
# 29996          799            3.8   Oka  Clothing and Accessories
# 29997        4,999                  Oka  Clothing and Accessories
# 29998        3,125            3.8   Oka  Clothing and Accessories
# 29999        3,125                  Oka  Clothing and Accessories
#
#                crawled_at                                        description  \
# 0     2021-02-10 20:11:51  Yorker trackpants made from 100% rich combed c...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   actual_price     30000 non-null  object
#  1   average_rating   30000 non-null  object
#  2   brand            30000 non-null  object
#  3   category         30000 non-null  object
#  4   crawled_at       30000 non-null  datetime64[ns]
#  5   description      30000 non-null  object
#  6   discount         30000 non-null  object
#  7   images           30000 non-null  object
#  8   out_of_stock     30000 non-null  bool
#  9   pid              30000 non-null  object
#  10  product_details  30000 non-null  object
#  11  seller           30000 non-null  object
#  12  selling_price    30000 non-null  object
#  13  sub_category     30000 non-null  object
#  14  title            30000 non-null  object
#  15  url              30000 non-null  object
# ...

# %%
df.describe()
# Out:
# <ipython-input-12-ea8415b8a3ee>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe()
#        actual_price average_rating  brand                  category  \
# count         30000          30000  30000                     30000
# unique          729             39    325                         4
# top             999            3.9         Clothing and Accessories
# freq           3671           2690   2068                     28971
# first           NaN            NaN    NaN                       NaN
# last            NaN            NaN    NaN                       NaN
#
#                  crawled_at description discount images out_of_stock  \
# count                 30000       30000    30000  30000        30000
# ...

# %%
print(df['category'].unique())
# Out:
# ['Clothing and Accessories' 'Bags, Wallets & Belts' 'Footwear' 'Toys']

# %%
toys=df[df['category']=='Toys']

# %%
toys
# Out:
#       actual_price average_rating brand category          crawled_at  \
# 13944          499            3.6           Toys 2021-02-10 22:49:20
#
#                                              description discount  \
# 13944  Natali Traders presents hats for men or boys m...  62% off
#
#                                                   images  out_of_stock  \
# 13944  [https://rukminim1.flixcart.com/image/128/128/...         False
#
#                     pid                                    product_details  \
# 13944  HATEZMCYMGPRQWVK  [{'Sales Package': '1 Hat'}, {'Number of Conte...
#
#         seller selling_price    sub_category  \
# 13944  FA SHOP           189  Party Supplies
#
#                                          title  \
# 13944  Natali Traders Fedora  (Red, Pack of 1)
#
#                                                      url
# 13944  https://www.flipkart.com/natali-traders-fedora...

# %%
cl=df[df['category']=='Clothing and Accessories']

# %%
cl['average_rating'] = cl['average_rating'].replace('', 0)
cl
# Out:
# <ipython-input-23-ad87316b7d67>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl['average_rating'] = cl['average_rating'].replace('', 0)
#       actual_price average_rating brand                  category  \
# 0            2,999            3.9  York  Clothing and Accessories
# 1            1,499            3.9  York  Clothing and Accessories
# 2            2,999            3.9  York  Clothing and Accessories
# 3            2,999            3.9  York  Clothing and Accessories
# 4            2,999            3.9  York  Clothing and Accessories
# ...            ...            ...   ...                       ...
# 29995        2,299              0   Oka  Clothing and Accessories
# ...

# %%
cl['average_rating'] = cl['average_rating'].astype(float)
cl
# Out:
# <ipython-input-24-15d2fd72bcf7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl['average_rating'] = cl['average_rating'].astype(float)
#       actual_price  average_rating brand                  category  \
# 0            2,999             3.9  York  Clothing and Accessories
# 1            1,499             3.9  York  Clothing and Accessories
# 2            2,999             3.9  York  Clothing and Accessories
# 3            2,999             3.9  York  Clothing and Accessories
# 4            2,999             3.9  York  Clothing and Accessories
# ...            ...             ...   ...                       ...
# 29995        2,299             0.0   Oka  Clothing and Accessories
# ...

# %%
cl['sub_category'].nunique()
# Out:
# 16

# %%
clsub=cl['sub_category'].unique()
clsub
# Out:
# array(['Bottomwear', 'Clothing Accessories', 'Winter Wear', 'Raincoats',
#        'Topwear', 'Innerwear and Swimwear',
#        'Kurtas, Ethnic Sets and Bottoms', 'Blazers, Waistcoats and Suits',
#        'Tracksuits', 'Sleepwear', 'Crocks Club Clothing and Accessories',
#        'Fabrics', 'Inspire Clothing and Accessories',
#        'INSPIRE Clothing and Accessories', 'Roy Clothing and Accessories',
#        'Uber Urban Clothing and Accessories'], dtype=object)

# %%
cltop=cl[cl['sub_category']=='Topwear']

# %%
cltop
# Out:
#       actual_price  average_rating          brand                  category  \
# 173            569             3.8  DISCOUNT OUTL  Clothing and Accessories
# 174            569             3.8  DISCOUNT OUTL  Clothing and Accessories
# 175            569             3.8  DISCOUNT OUTL  Clothing and Accessories
# 176            449             4.8  DISCOUNT OUTL  Clothing and Accessories
# 177          1,499             4.3  DISCOUNT OUTL  Clothing and Accessories
# ...            ...             ...            ...                       ...
# 29977          999             3.8            Oka  Clothing and Accessories
# 29979          999             3.8            Oka  Clothing and Accessories
# 29983          999             3.8            Oka  Clothing and Accessories
# 29984          999             3.8            Oka  Clothing and Accessories
# 29993          550             4.3            Oka  Clothing and Accessories
#
# ...

# %%
cltopsell=cltop[cltop['selling_price']>'500']

# %%
cltopsell
# Out:
#       actual_price  average_rating          brand                  category  \
# 208          1,625             4.3  DISCOUNT OUTL  Clothing and Accessories
# 212          1,625             4.3  DISCOUNT OUTL  Clothing and Accessories
# 214          1,625             4.3  DISCOUNT OUTL  Clothing and Accessories
# 219          1,625             4.3  DISCOUNT OUTL  Clothing and Accessories
# 239          1,625             4.3  DISCOUNT OUTL  Clothing and Accessories
# ...            ...             ...            ...                       ...
# 29935          999             3.8            Oka  Clothing and Accessories
# 29937          999             0.0            Oka  Clothing and Accessories
# 29945          999             3.8            Oka  Clothing and Accessories
# 29959          999             0.0            Oka  Clothing and Accessories
# 29970        1,149             3.8            Oka  Clothing and Accessories
#
# ...

# %%
# @title average_rating

from matplotlib import pyplot as plt
cl['average_rating'].plot(kind='hist', bins=20, title='average_rating')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
cl['seller'].nunique()
# Out:
# 516
